# %%
import sqlite3

conn= sqlite3.connect('record.db')
print('open database success')

print("list of joined data")
cursor = conn.execute("SELECT text, text_clean FROM record")

for row in cursor:
    print(row)
    print()
    print("operantion done succesfully")
# Out:
# open database success
# list of joined data
# ('WJDDEJDEJ!@@## http', 'WJDDEJDEJ!@@## http')
#
# operantion done succesfully
# ('hthehech !!!', 'hthehech !!!')
#
# operantion done succesfully
# ('wdnebcIIIWWW1!!1', 'wdnebc          ')
#
# operantion done succesfully
# ('jejdnowoeQQ1122!!!', 'jejdnowoe         ')
#
# operantion done succesfully
# ('Wah Senangnya111!!!@', 'Wah Senangnya111    ')
#
# operantion done succesfully
# ('AADDH', 'AADDH')
#
# operantion done succesfully
# ('WAHH!!! APA IYA???', 'WAHH    APA IYA   ')
#
# operantion done succesfully
# ('WAHH!!! APA IYA??? ww.hapee.com', 'WAHH    APA IYA    ww hapee com')
#
# operantion done succesfully
# ('AA!HHDIhddh333', 'AA HHDIhddh333')
#
# operantion done succesfully
# ('AA!HHDIhddh333!!!!', 'AA HHDIhddh333    ')
#
# operantion done succesfully
# ('QQQW12238(&@^#%^', 'QQQW12238       ')
#
# operantion done succesfully
# ('dsdw1123__+)@&@', 'dsdw1123__     ')
#
# operantion done succesfully
# ('hdhu@%!$@^@', 'hdhu       ')
# ...
